# %% [markdown]
# # Demo
# Generate data, train, and evaluate.

# %%
# !python scripts/generate_synthetic.py --out data/sample/synth_prices.csv --n_steps 1000

# %%
# !python main.py --config configs/default.yaml

# %%
from pinn_volatility.evaluate import evaluate_main
evaluate_main('runs/last.pt', 'data/sample/synth_prices.csv')
